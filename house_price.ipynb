# %% [markdown]
# <a href="https://colab.research.google.com/github/Terrich-hash/ai/blob/main/house_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("house price vs area(Sheet1).csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area (sq feet)')
plt.ylabel('price (us$)')
plt.scatter(df.area,df.price ,color='red' ,marker='*')
plt.plot(df.area,reg.predict(df[['area']]),color='blue')#it is added after training

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
#y=m*area+b
135.78767123*3300+180616.43835616432
# Out:
# 628715.7534151643

# %%
d = pd.read_csv("house price vs area(Sheet2).csv")
d.head(4)
# Out:
#    area
# 0  1000
# 1  2000
# 2  6000
# 3  7000

# %%
p =reg.predict(d)
p
# Out:
# array([ 316404.10958904,  452191.78082192,  995342.46575342,
#        1131130.1369863 ,  710188.35616438,  737345.89041096,
#         465770.54794521, 1375547.94520548,  778082.19178082])

# %%
d['prices']=p
d    #to convert in csv use. ex- to_csv("pridction.csv") exclude index no. ,index=False
# Out:
#    area        prices
# 0  1000  3.164041e+05
# 1  2000  4.521918e+05
# 2  6000  9.953425e+05
# 3  7000  1.131130e+06
# 4  3900  7.101884e+05
# 5  4100  7.373459e+05
# 6  2100  4.657705e+05
# 7  8800  1.375548e+06
# 8  4400  7.780822e+05
