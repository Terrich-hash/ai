# %% [markdown]
# <a href="https://colab.research.google.com/github/Terrich-hash/ai/blob/main/test_score_grad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import math

# %%
'''def predict_using_sklearn():
  df=pd.read_csv('test_scores.csv')
  r=linear_model.LinearRegression()
  r.fit(df[['math']],df.cs)
  return r.coef_,r.intercept_'''

# %%
def gradient_descent(x,y):
  m_curr=b_curr=0
  itteration=10000
  n=len(x)
  learning_rate=0.02
  cost_previous=0


  for i in range(itteration):
    y_predicted=m_curr*x+b_curr
    cost=(1/n)*sum([val**2 for val in (y-y_predicted)])
    md= -(2/n)*sum(x*(y-y_predicted))
    bd=-(2/n)*sum(y-y_predicted)
    m_curr=m_curr-learning_rate*md
    b_curr=b_curr-learning_rate*bd
    if math.isclose(cost, cost_previous, rel_tol=1e-20):
      break
    cost_previous = cost
    print ('m{},b{},cost{},itteration{}'.format(m_curr,b_curr,cost,i))
  return m_curr ,b_curr

# %%
df=pd.read_csv('test_scores.csv')
x = df['math'].values
y = df['cs'].values
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
gradient_descent(x,y)
# Out:
# m197.836,b2.7960000000000003,cost5199.1,itteration0
# m-37074.023872,b-523.1376319999999,cost183406181.08900163,itteration1
# m6984858.796282623,b98562.375659264,cost6509761915250.626,itteration2
# m-1315931163.6995568,b-18568920.027034275,cost2.310555036438643e+17,itteration3
# m247918410346.59683,b3498341908.975263,cost8.201013563846335e+21,itteration4
# m-46707259342267.945,b-659079584210.6946,cost2.9108427375119826e+26,itteration5
# m8799540430358798.0,b124169080561700.5,cost1.033165641851756e+31,itteration6
# m-1.657813215245644e+18,b-2.3393169712579476e+16,cost3.6670866129144685e+35,itteration7
# m3.123282037731416e+20,b4.407219468212284e+18,cost1.3015845360976533e+40,itteration8
# m-5.884191655312801e+22,b-8.303100297923506e+20,cost4.6198044481477765e+44,itteration9
# m1.1085681990346798e+25,b1.564285034013574e+23,cost1.639739298310527e+49,itteration10
# m-2.088517036662812e+27,b-2.9470770914941346e+25,cost5.820040645880369e+53,itteration11
# ...
